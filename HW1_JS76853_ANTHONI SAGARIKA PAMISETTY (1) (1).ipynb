# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.1
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.11.7
# astropy                       5.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.9.1
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# basemap                       1.3.8
# basemap-data                  1.3.2
# bcrypt                        3.2.0
# ...

# %%
# !pip install pandas

# %%
# !pip install nltk

# %%
import nltk

# %%
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# ...

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# !pip install matplotlib

# %% [markdown]
# ----->Question 1
#
# Que-6: Produce a dispersion plot of the four main protagonists in Sense and Sensibility:
# Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
import matplotlib.pyplot as plt

# %%
text2.dispersion_plot(["Elinor","Marianne","Edward","Willoughby"])

# %% [markdown]
# from the above dispersion plot ,the dispersion likely coincides with these two pairs :
#
# #pair 1 ( Edward and Elinor)
# #pair 2 (Willoughby and Marianne)

# %% [markdown]
# Lets check by using some context if the two characters in each pair appear close

# %%
 set(text2)
# Out:
# {'supposed',
#  'extolling',
#  'concluding',
#  '.',
#  'seeming',
#  'inexperience',
#  'everybody',
#  'earlier',
#  'tower',
#  'bowling',
#  '27',
#  'your',
#  'carelessly',
#  'paper',
#  'confidential',
#  'ingratiating',
#  'infer',
#  'LUCY',
#  'effects',
#  'dare',
#  'venture',
#  'assisting',
#  'obligingly',
#  'delighful',
#  'submission',
#  'something',
#  'Selfish',
#  'liberality',
#  'hearty',
#  'charms',
#  'long',
#  'liveliness',
#  'aside',
#  'anxiety',
#  'Come',
#  'Thus',
#  'disorder',
#  'lock',
#  'rung',
#  'instigation',
#  'London',
#  'famous',
#  'painful',
#  '?',
#  'knew',
#  'submissive',
#  'state',
#  'pride',
#  'abridge',
#  'accepting',
#  'appear',
#  'appeal',
#  'dismissed',
#  'likes',
#  'conclusion',
#  'hardily',
#  'men',
#  'deemed',
#  'heart',
#  'reconcile',
#  'supplanted',
#  'doors',
#  'avail',
#  'bent',
#  'invent',
#  'Dawlish',
#  'yard',
#  'series',
#  'We',
#  'looking',
#  'failed',
#  'friendly',
#  'befallen',
# ...

# %%
#using a function to identify if two characters occur more frequently in the given text

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
#Using concept of w for w from documentation

# %% [markdown]
# Question 2-----> The first sentence of text3 is provided to you in the variable sent3. The index of the in sent3 is 1, because sent3[1] gives us 'the'. What are the indexes of the two other occurrences of this word in sent3?

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
find_the = [w for w in sent3] 
# Running a for loop and checking if the word at present is equal to "the"
indexes = [i for i,word in enumerate(find_the) if word == "the"] 
print(indexes)
# Out:
# [1, 5, 8]

# %%
#So the other two indexes/Occurance of "the" in the first sentence are 5,8

# %% [markdown]
# --->Question 3
#
# Use text9.index() to find the index of the word sunset. You’ll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
text9
# Out:
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>

# %%
text9.index('sunset')
# Out:
# 629

# %%
sent1 = text9[600:650]
print(sent1)
# Out:
# [',', 'and', 'you', 'may', 'safely', 'read', '.', 'G', '.', 'K', '.', 'C', '.', 'CHAPTER', 'I', 'THE', 'TWO', 'POETS', 'OF', 'SAFFRON', 'PARK', 'THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset', 'side', 'of', 'London', ',', 'as', 'red', 'and', 'ragged', 'as', 'a', 'cloud', 'of', 'sunset', '.', 'It', 'was', 'built', 'of', 'a', 'bright']

# %% [markdown]
# from the above slice we can say the Sentence starts from CHAPTER and ends after sunset.
# Considering Full stops for this condition

# %%
for index, word in enumerate(sent1):
    if word == '.':
        print(index)
# Out:
# 6
# 8
# 10
# 12
# 43

# %%
## reducing the slicing interval

# %%
sent2 = text9[613:651]
print(sent2)
# Out:
# ['CHAPTER', 'I', 'THE', 'TWO', 'POETS', 'OF', 'SAFFRON', 'PARK', 'THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset', 'side', 'of', 'London', ',', 'as', 'red', 'and', 'ragged', 'as', 'a', 'cloud', 'of', 'sunset', '.', 'It', 'was', 'built', 'of', 'a', 'bright', 'brick']

# %%
for index, word in enumerate(sent2):
    if word == '.':
        print(index)
# Out:
# 30

# %%
#slicing it to the 30 index

# %%
sent3 = text9[613:630]
print(sent3)
# Out:
# ['CHAPTER', 'I', 'THE', 'TWO', 'POETS', 'OF', 'SAFFRON', 'PARK', 'THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset']

# %% [markdown]
# Question ----> 4  difference between the following two tests: w.isupper() and not w.islower()
#
#  Ans:It is a boolean function where it checks the given word is upper or not --- > w.isupper()
# It is a boolean function where it checks the given word is lower or not --- > w.islower()

# %%
w = 'sagar'

W = w.isupper()
print(W)

W=w.islower()
print(W)
# Out:
# False
# True

# %% [markdown]
# Question--->5: Define a function percent(word, text) that calculates how often a given word occurs in a text and expresses the result as a percentage.

# %%
#The below function identifies the percentage of word "the" in text4

# %%
def percentage(count, total):
    return 100 * count / total

# %%
percentage(text4.count('the'), len(text4))
# Out:
# 6.249141601428375

# %% [markdown]
# Question---> 6 We have been using sets to store vocabularies. Try the following Python expression:
# set(sent3) < set(text1). Experiment with this using different arguments to
# set(). What does it do? Can you think of a practical application for this?

# %%
set(sent3) < set(text1)
# Out:
# False

# %%
set(sent3)  > set(text1)
# Out:
# False

# %%
print(set(sent3))
# Out:
# {'POETS', 'the', 'THE', 'suburb', 'lay', 'sunset', 'CHAPTER', 'SAFFRON', 'PARK', 'TWO', 'Park', 'on', 'of', 'Saffron', 'I', 'OF'}

# %%
print(set(text1))
# Out:
# {'foreshadowing', 'supposed', 'afternoons', 'GOETHE', 'chivalric', 'concluding', '.', 'Doubtless', 'REFERENCE', 'straw', 'underived', 'seeming', 'Provoke', 'solicitously', 'rehearsing', 'remnant', 'inexperience', 'everybody', 'rollings', 'earlier', 'mongrel', 'tower', 'bowling', 'gambol', '27', 'humped', 'inflexible', 'your', 'popularize', 'flows', 'carelessly', 'faced', 'reptile', 'SETH', 'nonce', 'Whole', 'chrysalis', 'paper', 'Lad', 'Unmindful', 'sweeping', 'confidential', 'flooded', 'bland', 'wakefulness', 'motioning', 'Hampton', 'rimmed', 'effects', 'fringing', 'blacksmith', 'dare', 'leash', 'fidelities', 'venture', 'bastions', 'hieroglyphic', 'assisting', 'integument', 'Riotous', 'wickedness', 'yonder', 'engrossing', 'Englishmen', 'cucumbers', 'obtruding', 'boomed', 'VERBAL', 'submission', 'livelihood', 'pomps', 'something', 'deafened', 'ignoring', 'hearty', 'si', 'orbs', 'volley', 'gasps', 'satins', 'sacramental', 'migrating', 'charms', 'employs', 'long', 'pictorial', 'windy',
# ...

# %% [markdown]
# I would say the above condition checks if entire words in the sentence are present in the text1
#
# Since the entire set of words are not present in the text1 it returns false
#
# One practical example i would think of is set(user_passwords) < set(common_passwords) choosing the passwords aptly
#
# eg : Choosing 8 character passwords for signing up
