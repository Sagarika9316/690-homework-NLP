# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# basemap                            1.3.8
# basemap-data                       1.3.2
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# blis                               0.7.5
# bokeh                              2.3.2
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# catalogue                          2.0.6
# certifi                            2020.12.5
# cffi                               1.14.5
# chardet                            4.0.0
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.9
# conda                              4.10.1
# conda-build                        3.21.4
# conda-content-trust                0+unknown
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cryptography                       3.4.7
# cycler                             0.10.0
# cymem                              2.0.6
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.6
# defusedxml                         0.7.1
# Deprecated                         1.2.14
# diff-match-patch                   20200713
# distributed                        2021.4.0
# docutils                           0.17
# en-core-web-sm                     3.1.0
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.9.0
# Flask                              1.1.2
# fsspec                             0.9.0
# future                             0.18.2
# geographiclib                      2.0
# geopy                              2.4.0
# geos                               0.2.3
# gevent                             21.1.2
# glob2                              0.7
# greenlet                           1.0.0
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 3.10.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isort                              5.8.0
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# keyring                            22.3.0
# kiwisolver                         1.3.1
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# MarkupSafe                         1.1.1
# matplotlib                         3.3.4
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# murmurhash                         1.0.6
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# neattext                           0.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.24.4
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.7
# packaging                          20.9
# pandas                             1.2.4
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# pathy                              0.6.1
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.2.0
# pip                                21.0.1
# pkginfo                            1.7.0
# pluggy                             0.13.1
# ply                                3.11
# preshed                            3.0.6
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# py4j                               0.10.9.7
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydantic                           1.8.2
# pydocstyle                         6.0.0
# pyerfa                             1.7.3
# pyflakes                           2.2.0
# PyGithub                           2.1.1
# Pygments                           2.8.1
# PyJWT                              2.8.0
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pypdf2                             3.0.1
# pyproj                             3.5.0
# pyreadline                         2.1
# pyrsistent                         0.17.3
# pyshp                              2.3.1
# PySocks                            1.7.1
# pyspark                            3.5.0
# pyspellchecker                     0.7.2
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# regex                              2021.4.4
# requests                           2.25.1
# rope                               0.18.0
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scipy                              1.6.2
# seaborn                            0.11.1
# Send2Trash                         1.5.0
# setuptools                         52.0.0.post20210125
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# smart-open                         5.2.1
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# spacy                              3.1.4
# spacy-legacy                       3.0.8
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# srsly                              2.4.2
# statsmodels                        0.12.2
# sympy                              1.8
# tables                             3.6.1
# tabulate                           0.9.0
# tblib                              1.7.0
# terminado                          0.9.4
# testpath                           0.4.4
# textblob                           0.17.1
# textdistance                       4.2.1
# thinc                              8.0.12
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# toml                               0.10.2
# toolz                              0.11.1
# torch                              1.9.0
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# typed-ast                          1.4.2
# typer                              0.4.0
# typing-extensions                  4.8.0
# ujson                              4.0.2
# unicodecsv                         0.14.1
# urllib3                            1.26.4
# wasabi                             0.8.2
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wget                               3.2
# wheel                              0.36.2
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\mansur\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\mansur\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\mansur\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mansur\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\mansur\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\mansur\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: joblib in c:\users\mansur\anaconda3\lib\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\mansur\anaconda3\lib\site-packages (from nltk) (4.59.0)
# Requirement already satisfied: click in c:\users\mansur\anaconda3\lib\site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex in c:\users\mansur\anaconda3\lib\site-packages (from nltk) (2021.4.4)

# %%
import nltk
# Out:
# C:\Users\Mansur\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\Mansur\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection book
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.48.1-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.2 kB ? eta -:--:--
#      ---- -------------------------------- 20.5/162.2 kB 330.3 kB/s eta 0:00:01
#      --------------------------------- ---- 143.4/162.2 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 162.2/162.2 kB 1.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\sagar\miniconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sagar\miniconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\sagar\miniconda3\lib\site-packages (from matplotlib) (10.0.1)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sagar\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\sagar\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.8.2-cp311-cp311-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.6 MB 7.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/7.6 MB 5.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.6 MB 5.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.6 MB 4.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/7.6 MB 5.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/7.6 MB 5.1 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/7.6 MB 5.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/7.6 MB 4.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.6 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.3/7.6 MB 5.1 MB/s eta 0:00:02
#    ------------- -------------------------- 2.5/7.6 MB 5.1 MB/s eta 0:00:02
#    -------------- ------------------------- 2.7/7.6 MB 5.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.1/7.6 MB 5.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.3/7.6 MB 5.2 MB/s eta 0:00:01
#    ------------------ --------------------- 3.6/7.6 MB 5.3 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/7.6 MB 5.3 MB/s eta 0:00:01
#    --------------------- ------------------ 4.0/7.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.3/7.6 MB 5.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.5/7.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------ --------------- 4.7/7.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------- -------------- 4.9/7.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.1/7.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.4/7.6 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.6/7.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.9/7.6 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.1/7.6 MB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 6.3/7.6 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.6/7.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------ --- 6.9/7.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 7.3/7.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  7.6/7.6 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 5.2 MB/s eta 0:00:00
# Downloading contourpy-1.2.0-cp311-cp311-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.6 kB ? eta -:--:--
#    --------------------------------------  184.3/187.6 kB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 187.6/187.6 kB 5.5 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.48.1-cp311-cp311-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.2 MB 9.3 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.2 MB 7.0 MB/s eta 0:00:01
#    ------------ --------------------------- 0.7/2.2 MB 5.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.2 MB 6.0 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.2 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 6.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.9/2.2 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB 3.1 MB/s eta 0:00:00
# Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 fonttools-4.48.1 kiwisolver-1.4.5 matplotlib-3.8.2 pyparsing-3.1.1

# %% [markdown]
# ----->Question 1
#
# Que-6: Produce a dispersion plot of the four main protagonists in Sense and Sensibility:
# Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
import matplotlib.pyplot as plt

# %%
text2.dispersion_plot(["Elinor","Marianne","Edward","Willoughby"])

# %% [markdown]
# from the above dispersion plot ,the dispersion likely coincides with these two pairs :
#
# #pair 1 ( Edward and Elinor)
# #pair 2 (Willoughby and Marianne)

# %% [markdown]
# Lets check by using some context if the two characters in each pair appear close

# %%
 set(text2)
# Out:
# {'ham',
#  'endowed',
#  'fly',
#  'affected',
#  'mean',
#  'Improve',
#  'represented',
#  'instigated',
#  'wildest',
#  'complexion',
#  'sobered',
#  'gross',
#  'reasonings',
#  'wrapped',
#  'Dashwoods',
#  'potent',
#  'gaiety',
#  'perverseness',
#  'features',
#  'commonly',
#  'dispersing',
#  'pursuits',
#  'unpleasant',
#  'loved',
#  'bottom',
#  'rouse',
#  'amiably',
#  'rocks',
#  'hold',
#  'lessen',
#  'Tell',
#  'encouraging',
#  'magnificent',
#  'reduced',
#  'widow',
#  'submissive',
#  'containing',
#  'incommode',
#  'doing',
#  'indolence',
#  'quite',
#  'screened',
#  'Remember',
#  'enrich',
#  'exhilarated',
#  'resources',
#  'stipulate',
#  'increased',
#  'winding',
#  'treasured',
#  'suspecting',
#  'ears',
#  'submitted',
#  'compare',
#  'displeased',
#  'habitual',
#  'wait',
#  'ages',
#  'behind',
#  'hospitality',
#  'clouds',
#  'guineas',
#  'shook',
#  'memorable',
#  'quarrel',
#  'expected',
#  'Honiton',
#  'alternately',
#  'insured',
#  'endeavour',
#  'unobtrusiveness',
#  'terms',
#  'vanity',
#  'dearly',
#  'Careless',
#  'dealt',
#  'Dennison',
#  'firmly',
#  'correspondence',
#  'conjecturing',
#  'disappointing',
#  'pleasanter',
#  'who',
#  'Choice',
#  'evening',
#  'assure',
#  'slightest',
#  'scrupled',
#  'fixed',
#  'Two',
#  'chatty',
#  'rushed',
#  'flatteries',
#  'discharged',
#  'benevolence',
#  'disgusting',
#  'country',
#  'regularity',
#  'm',
#  'befallen',
#  'fancy',
#  'decay',
#  'remains',
#  'forms',
#  'undeserving',
#  'plead',
#  'intervals',
#  'appointment',
#  'inferior',
#  'intermission',
#  'banished',
#  'spirits',
#  'promontories',
#  'WILL',
#  'unexpected',
#  'indignity',
#  'ay',
#  'warranted',
#  'panting',
#  'systems',
#  'act',
#  'opened',
#  'settling',
#  'cure',
#  'indigence',
#  'exciting',
#  'ordained',
#  'proposed',
#  'frugality',
#  'promises',
#  'terror',
#  'excuses',
#  'd',
#  'rose',
#  'upright',
#  'pinching',
#  'desired',
#  'inhabited',
#  'assembled',
#  'gossip',
#  'gazing',
#  'waited',
#  'usual',
#  'equals',
#  'cant',
#  'accusation',
#  'mass',
#  'extent',
#  'reasonable',
#  'Business',
#  'obliging',
#  'bashful',
#  'motionless',
#  'gentleman',
#  'topic',
#  'healthful',
#  'infancy',
#  'reproving',
#  'attendance',
#  'bred',
#  'coats',
#  'inventing',
#  'obey',
#  'diminution',
#  'whom',
#  'ceiling',
#  'solely',
#  'directions',
#  'things',
#  'sooner',
#  'peace',
#  'maintained',
#  'virtuous',
#  'pitched',
#  'singly',
#  'chamber',
#  'fretful',
#  'patience',
#  'virtues',
#  'oh',
#  'proper',
#  'fond',
#  ':',
#  'perseverance',
#  'Whereas',
#  'restore',
#  'claim',
#  'IN',
#  'conquest',
#  'perfections',
#  'INconvenience',
#  'minds',
#  'stared',
#  'biased',
#  'Middleton',
#  'tidings',
#  'unlike',
#  'yard',
#  'incurable',
#  'threatening',
#  'Gardens',
#  'avoided',
#  'trusting',
#  '!\'"',
#  'annuity',
#  'injustice',
#  'chairs',
#  'respected',
#  'nettles',
#  'endurance',
#  'procure',
#  'flatter',
#  'nodding',
#  'fastidious',
#  'circumstance',
#  'Far',
#  'puppyism',
#  'emptiness',
#  'harshly',
#  'uselessly',
#  'unseen',
#  'firm',
#  'scale',
#  'impression',
#  'evince',
#  'owed',
#  'traced',
#  'guilt',
#  'douceur',
#  'written',
#  'misapprehension',
#  'uncomfortable',
#  'cramps',
#  'refrain',
#  'story',
#  'apartments',
#  'imply',
#  'impoverishing',
#  'ones',
#  'proportion',
#  'residing',
#  'moonlight',
#  'hackneyed',
#  'capable',
#  'raise',
#  '7000L',
#  ',"',
#  'patronised',
#  'contributing',
#  'Don',
#  'resume',
#  'accomplished',
#  'restraints',
#  'visit',
#  'minutes',
#  'get',
#  'consultation',
#  'tending',
#  'south',
#  'unison',
#  'humouring',
#  'judicious',
#  'darling',
#  'selfishness',
#  'believing',
#  'revived',
#  'considered',
#  'gales',
#  'have',
#  'broad',
#  'symptom',
#  'restraint',
#  'nobleman',
#  'statement',
#  'familiarized',
#  'beaux',
#  ".'",
#  'abhorrence',
#  'boasting',
#  'inforce',
#  'knees',
#  'obligations',
#  'defined',
#  'took',
#  'obeyed',
#  'deliberating',
#  'pleasures',
#  'Dashwood',
#  'conjectured',
#  'thunderbolt',
#  'partial',
#  'reasoning',
#  'undesirable',
#  'talk',
#  'sleepless',
#  'restrained',
#  'rich',
#  'neglect',
#  'sons',
#  'grieving',
#  'horrible',
#  'January',
#  'avowal',
#  ';--',
#  'mound',
#  'scruple',
#  'dine',
#  'produce',
#  'resolutely',
#  'spraining',
#  'contrived',
#  'unequal',
#  'Hunters',
#  'congratulations',
#  'unknowingly',
#  'consciousness',
#  'comforts',
#  'sharing',
#  'courtesy',
#  'existed',
#  'basis',
#  'Hon',
#  'daughter',
#  'amuse',
#  'humoured',
#  'dooming',
#  'subsist',
#  'land',
#  'augmenting',
#  'intrusion',
#  '19',
#  '?"',
#  'prepossessed',
#  'wander',
#  'deference',
#  'demur',
#  'tale',
#  'content',
#  'auspiciously',
#  'usage',
#  'conditioned',
#  'whims',
#  'prevailed',
#  'lips',
#  'conclusion',
#  'ESTEEM',
#  'created',
#  'presence',
#  'talking',
#  'bell',
#  'Gentleman',
#  'detecting',
#  'idled',
#  'those',
#  'professedly',
#  'unshaken',
#  'busy',
#  'first',
#  'senses',
#  'watch',
#  'acquitted',
#  'symptoms',
#  'Should',
#  'became',
#  'improved',
#  'departure',
#  'remarks',
#  'trembled',
#  'efficacy',
#  'projecting',
#  'petty',
#  'faithful',
#  'sunshine',
#  'climate',
#  'blinded',
#  'coxcombs',
#  'considerate',
#  'Valley',
#  'conveyed',
#  'idle',
#  'political',
#  'sentence',
#  'worship',
#  'premeditated',
#  'unsatiable',
#  'shade',
#  'honourably',
#  'followed',
#  'oppose',
#  'forbade',
#  'deny',
#  'Mine',
#  'pasturage',
#  'receiving',
#  'pronouncing',
#  'counsel',
#  'piqued',
#  'motives',
#  'lastingly',
#  'Our',
#  'after',
#  'thoroughly',
#  'imaginary',
#  'hesitation',
#  'plantations',
#  'charms',
#  'good',
#  'conspired',
#  'blessed',
#  'relatives',
#  'enough',
#  'acquit',
#  'animated',
#  'looking',
#  'forsaking',
#  'candid',
#  'blasted',
#  'dismissed',
#  'contrition',
#  'searched',
#  'spontaneous',
#  'seduction',
#  'irreproachable',
#  'villages',
#  'olives',
#  'insensibility',
#  'jacket',
#  'varying',
#  'villainy',
#  'bodily',
#  'cautious',
#  'prohibited',
#  'Exchange',
#  'mindful',
#  'equally',
#  'strike',
#  'accommodate',
#  'Brown',
#  'unreasonable',
#  'doors',
#  'referring',
#  'cod',
#  'expectation',
#  'considerations',
#  'rising',
#  'proportionately',
#  'exultation',
#  'for',
#  'disgust',
#  'Whenever',
#  'clearing',
#  'unusually',
#  'better',
#  'talents',
#  'tone',
#  'trust',
#  'composition',
#  'newly',
#  'steward',
#  'excessively',
#  'bustle',
#  'reliance',
#  'cessation',
#  'expressed',
#  'superior',
#  'respect',
#  'distractedly',
#  'flowed',
#  'call',
#  'send',
#  'worst',
#  'wearing',
#  'shrubbery',
#  'recurrence',
#  'hardly',
#  'vague',
#  'unites',
#  'Streets',
#  '8',
#  'keeps',
#  'cheerless',
#  'complain',
#  'lief',
#  'Time',
#  'fallen',
#  'heaven',
#  'passionately',
#  'availed',
#  'fears',
#  'unpleasantest',
#  'inquisitive',
#  'fetching',
#  'confirm',
#  'rested',
#  'rap',
#  'supplanted',
#  'addition',
#  'Christmas',
#  'nieces',
#  'To',
#  'anguish',
#  'matters',
#  'affixed',
#  'wooded',
#  'possess',
#  'nine',
#  'firmer',
#  'mistress',
#  'discarded',
#  'wept',
#  'dissimilar',
#  'bowling',
#  'musical',
#  'awkwardness',
#  'doubtless',
#  'expel',
#  'connoisseur',
#  'twelve',
#  'Willoughbys',
#  'Luckily',
#  'either',
#  'Inn',
#  'continuing',
#  'still',
#  'resolution',
#  'excellent',
#  'strangeness',
#  'recovered',
#  'viewed',
#  'shews',
#  'contradict',
#  'undergone',
#  'House',
#  'falls',
#  'circles',
#  'later',
#  'disposal',
#  'east',
#  'ungrateful',
#  'summits',
#  'amused',
#  'replying',
#  'compliments',
#  'gentlemanlike',
#  'withdrew',
#  'philippic',
#  'indignantly',
#  'dissipation',
#  'contents',
#  'loitered',
#  'deprive',
#  '28',
#  'resembled',
#  'haste',
#  'tolerably',
#  'Tuesday',
#  'Knowing',
#  'William',
#  'thirteen',
#  'detection',
#  'kicked',
#  'glebe',
#  'removing',
#  'hussy',
#  'amendment',
#  'anticipated',
#  'fascinating',
#  'matter',
#  'importunate',
#  'Sometimes',
#  'performance',
#  'recollected',
#  'display',
#  'appointed',
#  'infamously',
#  'surprised',
#  'reverie',
#  'strongest',
#  'letter',
#  'popt',
#  'questions',
#  'privacy',
#  'arrival',
#  'occupation',
#  'grew',
#  'decided',
#  'similarity',
#  'sort',
#  'welfare',
#  'feeling',
#  'extorting',
#  'soul',
#  'suggested',
#  'tempted',
#  'deterred',
#  'thence',
#  'respective',
#  'oneself',
#  'prospects',
#  'wild',
#  'gravely',
#  '.--',
#  'deceitful',
#  'inner',
#  'welcome',
#  'entrance',
#  'readily',
#  ':--"',
#  'spite',
#  'robbing',
#  'piece',
#  'knowledge',
#  'relations',
#  'calmly',
#  'impertinently',
#  'surviving',
#  'show',
#  'very',
#  'tied',
#  'worthy',
#  'militated',
#  'horrors',
#  'great',
#  'pure',
#  ';"--',
#  'staid',
#  'sympathised',
#  'command',
#  'Beyond',
#  'stylish',
#  'explanation',
#  'exchanged',
#  'luckily',
#  'circumstances',
#  'lamentation',
#  'scanty',
#  'cut',
#  'the',
#  'straight',
#  'last',
#  'leant',
#  'illiterate',
#  'injuries',
#  'nay',
#  'diverted',
#  'SOMETIMES',
#  'observe',
#  'October',
#  'What',
#  'chair',
#  'Marlborough',
#  'Early',
#  'insulted',
#  'spirit',
#  'originated',
#  'Quite',
#  'hanging',
#  'hither',
#  'Something',
#  'suitor',
#  'ELINOR',
#  'improvements',
#  'humored',
#  'conceal',
#  'bonnet',
#  'healthy',
#  'Careys',
#  '34',
#  'Engaged',
#  'horse',
#  'Vanity',
#  'suspicions',
#  'sweet',
#  'uncertain',
#  'unchanging',
#  'awakened',
#  'quickest',
#  'fate',
#  'integrity',
#  'set',
#  'dearer',
#  'shewn',
#  'refuse',
#  'fertile',
#  'effected',
#  'descend',
#  'perceiving',
#  'abridge',
#  'acknowledge',
#  'St',
#  'prose',
#  'laughter',
#  'reproved',
#  'imperfect',
#  'vain',
#  'hope',
#  'relative',
#  'identify',
#  'prove',
#  'months',
#  'colder',
#  'living',
#  'active',
#  'tallest',
#  'habitation',
#  'distinction',
#  'Were',
#  'walks',
#  'compromise',
#  'removed',
#  'lane',
#  'mistrust',
#  'bitter',
#  'humiliating',
#  'US',
#  'hearing',
#  'busily',
#  'thanks',
#  'cheek',
#  'coldness',
#  'weathered',
#  'determined',
#  'Music',
#  'everything',
#  'Brandon',
#  'drawn',
#  'Is',
#  'stiffly',
#  'protestations',
#  'following',
#  'rage',
#  'festival',
#  'pangs',
#  'That',
#  'trim',
#  'unaccountable',
#  'testimony',
#  'liveliness',
#  'Sandersons',
#  'does',
#  'contentment',
#  'nipped',
#  'brightness',
#  'wounding',
#  'slope',
#  'gaze',
#  'independently',
#  'left',
#  'fervent',
#  'unfair',
#  'auditors',
#  'deliver',
#  'demesne',
#  'salutation',
#  'outweigh',
#  'confounded',
#  'wish',
#  'production',
#  'meals',
#  'orator',
#  'manly',
#  'necessitous',
#  'size',
#  'marries',
#  'gravel',
#  'paused',
#  'dispose',
#  'importance',
#  'rascal',
#  'admission',
#  'Colonel',
#  'wide',
#  'alterations',
#  'pain',
#  'named',
#  'rather',
#  'pay',
#  'bit',
#  'heavily',
#  'DOES',
#  'fall',
#  'profited',
#  'alienated',
#  'Come',
#  'suggesting',
#  'yesterday',
#  'longed',
#  'occasionally',
#  'useless',
#  'opening',
#  'forbore',
#  'ladies',
#  'pique',
#  'idolized',
#  'frightened',
#  'enforced',
#  'contraction',
#  'do',
#  'wishes',
#  'author',
#  'heavy',
#  'uneasy',
#  'drain',
#  'live',
#  'transport',
#  '--"',
#  'saint',
#  'Palmers',
#  'you',
#  'Nor',
#  'preserve',
#  'heighten',
#  'ONE',
#  'concise',
#  'variation',
#  'undecided',
#  'pulled',
#  'learned',
#  'going',
#  'resumed',
#  'fir',
#  'scrutinies',
#  'prompted',
#  'unusual',
#  'fatiguing',
#  'Affecting',
#  'disagreements',
#  'dreadful',
#  'sympathize',
#  'depending',
#  'companion',
#  'precisely',
#  'holding',
#  'sufferings',
#  'person',
#  'unintentional',
#  'dare',
#  'marriage',
#  'quit',
#  'however',
#  '31',
#  'residence',
#  'Norland',
#  'ascending',
#  'deserving',
#  'constant',
#  'greatly',
#  'rain',
#  'merriment',
#  'raillery',
#  'learnt',
#  'reputation',
#  'fitted',
#  'gratification',
#  'light',
#  'Sophia',
#  'barouches',
#  'pre',
#  'injure',
#  'drains',
#  'kisses',
#  'managed',
#  'hazarding',
#  'negligent',
#  'tall',
#  'zealously',
#  'artlessness',
#  'inquietude',
#  'styled',
#  'frequently',
#  'beloved',
#  'confused',
#  'ye',
#  'degrade',
#  'contained',
#  'reports',
#  'syllables',
#  'cheerfuller',
#  'dwell',
#  'representations',
#  'newspapers',
#  'defended',
#  'saucy',
#  'discern',
#  'obtain',
#  'unrestrained',
#  'nodded',
#  'bulk',
#  'Bristol',
#  'recollect',
#  'stomach',
#  'heightened',
#  'enthusiasm',
#  'curious',
#  'theme',
#  'concessions',
#  'acquiescence',
#  'valued',
#  'unkind',
#  'Most',
#  'examined',
#  'hunts',
#  'DID',
#  'bottoms',
#  'earnestness',
#  'grounded',
#  'consequent',
#  'gloom',
#  'leaves',
#  'lie',
#  'inspired',
#  'warmly',
#  'points',
#  'seated',
#  'unlucky',
#  'blackest',
#  'inexcusable',
#  'pace',
#  'poultry',
#  '42',
#  'library',
#  'without',
#  'joyfully',
#  'moderate',
#  'redeem',
#  'unembarrassed',
#  'hoped',
#  'evidently',
#  'recreating',
#  'convenient',
#  'tended',
#  'ambition',
#  'drawings',
#  'supplying',
#  'Reflection',
#  'condemning',
#  'obtained',
#  'dawdled',
#  'presumed',
#  'throw',
#  'safely',
#  'goes',
#  'preferred',
#  'possessing',
#  'Then',
#  'received',
#  'appetite',
#  'decently',
#  'management',
#  'truths',
#  'WITHOUT',
#  'secures',
#  'amended',
#  'landlord',
#  'provocation',
#  'effects',
#  'prevailing',
#  'fretted',
#  'acknowledging',
#  'zeal',
#  'guarded',
#  'dwelling',
#  'stop',
#  'disproportion',
#  ',)',
#  'through',
#  'next',
#  '37',
#  'revive',
#  'height',
#  'propose',
#  'trick',
#  'dancing',
#  'headstrong',
#  'arisen',
#  'worn',
#  'strive',
#  'housekeeper',
#  'All',
#  'engaging',
#  'delight',
#  'carriage',
#  'scissors',
#  'ruined',
#  'constrained',
#  'honorable',
#  'store',
#  'simplest',
#  'apricot',
#  'footsteps',
#  'Whitakers',
#  'drinking',
#  'lovers',
#  'placed',
#  'pattern',
#  'declining',
#  'crossness',
#  'seconded',
#  'calm',
#  'forget',
#  ...}

# %%
#using a function to identify if two characters occur more frequently in the given text

# %%
text3
# Out:
# <Text: The Book of Genesis>

# %%
#Using concept of w for w from documentation

# %% [markdown]
# Question 2-----> The first sentence of text3 is provided to you in the variable sent3. The index of the in sent3 is 1, because sent3[1] gives us 'the'. What are the indexes of the two other occurrences of this word in sent3?

# %%
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
find_the = [w for w in sent3] 
# Running a for loop and checking if the word at present is equal to "the"
indexes = [i for i,word in enumerate(find_the) if word == "the"] 
print(indexes)
# Out:
# [1, 5, 8]

# %%
#So the other two indexes/Occurance of "the" in the first sentence are 5,8

# %% [markdown]
# --->Question 3
#
# Use text9.index() to find the index of the word sunset. You’ll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
text9
# Out:
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>

# %%
text9.index('sunset')
# Out:
# 629

# %%
sent1 = text9[600:650]
print(sent1)
# Out:
# [',', 'and', 'you', 'may', 'safely', 'read', '.', 'G', '.', 'K', '.', 'C', '.', 'CHAPTER', 'I', 'THE', 'TWO', 'POETS', 'OF', 'SAFFRON', 'PARK', 'THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset', 'side', 'of', 'London', ',', 'as', 'red', 'and', 'ragged', 'as', 'a', 'cloud', 'of', 'sunset', '.', 'It', 'was', 'built', 'of', 'a', 'bright']

# %% [markdown]
# from the above slice we can say the Sentence starts from CHAPTER and ends after sunset.
# Considering Full stops for this condition

# %%
for index, word in enumerate(sent1):
    if word == '.':
        print(index)
# Out:
# 6
# 8
# 10
# 12
# 43

# %%
## reducing the slicing interval

# %%
sent2 = text9[613:651]
print(sent2)
# Out:
# ['CHAPTER', 'I', 'THE', 'TWO', 'POETS', 'OF', 'SAFFRON', 'PARK', 'THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset', 'side', 'of', 'London', ',', 'as', 'red', 'and', 'ragged', 'as', 'a', 'cloud', 'of', 'sunset', '.', 'It', 'was', 'built', 'of', 'a', 'bright', 'brick']

# %%
for index, word in enumerate(sent2):
    if word == '.':
        print(index)
# Out:
# 30

# %%
#slicing it to the 30 index

# %%
sent3 = text9[613:630]
print(sent3)
# Out:
# ['CHAPTER', 'I', 'THE', 'TWO', 'POETS', 'OF', 'SAFFRON', 'PARK', 'THE', 'suburb', 'of', 'Saffron', 'Park', 'lay', 'on', 'the', 'sunset']

# %% [markdown]
# Question ----> 4  difference between the following two tests: w.isupper() and not w.islower()
#
#  Ans:It is a boolean function where it checks the given word is upper or not --- > w.isupper()
# It is a boolean function where it checks the given word is lower or not --- > w.islower()

# %%
w = 'sagar'

W = w.isupper()
print(W)

W=w.islower()
print(W)
# Out:
# False
# True

# %% [markdown]
# Question--->5: Define a function percent(word, text) that calculates how often a given word occurs in a text and expresses the result as a percentage.

# %%
#The below function identifies the percentage of word "the" in text4

# %%
def percentage(count, total):
    return 100 * count / total

# %%
percentage(text4.count('the'), len(text4))
# Out:
# 6.249141601428375

# %% [markdown]
# Question---> 6 We have been using sets to store vocabularies. Try the following Python expression:
# set(sent3) < set(text1). Experiment with this using different arguments to
# set(). What does it do? Can you think of a practical application for this?

# %%
set(sent3) < set(text1)
# Out:
# False

# %%
print(set(sent3))
# Out:
# {'TWO', 'PARK', 'Saffron', 'suburb', 'of', 'I', 'lay', 'SAFFRON', 'OF', 'CHAPTER', 'sunset', 'POETS', 'Park', 'THE', 'on', 'the'}

# %%
print(set(text1))
# Out:
# {'fortresses', 'upwards', 'Inasmuch', 'heel', 'palmy', 'patrolled', 'ham', 'fly', 'consulting', 'affected', 'Dead', 'admeasurements', 'mean', 'rippling', 'represented', 'July', 'Bag', 'Liberties', 'spiles', 'stooped', 'empires', 'paralysis', 'vernacular', 'flexibility', 'acre', 'wildest', 'lege', 'EZEKIEL', 'clerical', 'SULKY', 'complexion', 'competent', 'pyramids', 'Consequently', 'gross', 'type', 'obeying', 'banner', 'lovings', 'wrapped', 'boarding', 'potent', 'tidiness', 'jawed', 'Wa', 'technicals', 'clotted', 'fashionables', 'beget', 'ibis', 'murderer', 'manifested', 'MCCULLOCH', 'graven', 'tester', 'Halloo', 'suffusingly', 'cocoa', 'lily', 'childish', 'pumps', 'features', 'impotently', 'commonly', 'exotic', 'normal', 'PURPOSE', 'tiara', 'sizes', 'Church', 'pursuits', 'loved', 'unpleasant', 'disobey', 'imbibing', 'loosely', 'fields', 'bottom', 'disaster', 'Archipelagoes', 'rouse', 'CROW', 'Harvard', 'flagon', 'manikin', 'Hard', 'Way', 'rocks', 'thenceforth', 'hold', 'AT', 'garnished', 'Tell', 'spelling', 'torso', 'SISTER', 'mainmast', 'incumbrance', 'threaten', 'midwinter', 'magnificent', 'vocation', 'freely', 'reduced', 'lowermost', 'symbolically', 'headless', 'widow', 'muzzle', 'whichever', 'containing', 'staving', 'shabbily', 'uttering', 'doing', 'counsels', 'stitch', 'sullenly', 'hater', 'furnaces', 'Heading', 'pendulous', 'quite', 'antique', 'Remember', 'cooking', 'wanings', '1850', 'uncivilized', 'Canada', 'SAIL', 'winding', 'increased', 'insects', 'Corinthians', 'incompetency', 'maidens', 'ISOLATO', 'suburban', 'anticipatingly', 'cheer', 'Seed', 'Aboard', 'suspecting', 'sustenance', 'Beat', 'lends', 'Words', 'crucifixion', 'soliloquizer', 'ears', 'wisely', 'submitted', 'compare', 'interpreter', 'intrepidity', 'radiance', 'wrapping', 'discount', 'intensified', 'flanking', 'perceptibly', 'constrain', 'Mordecai', 'bellied', 'Walking', 'Commons', 'bend', 'wait', 'habitual', 'tangle', 'humming', 'ages', 'behind', 'hospitality', 'Mendanna', 'Dish', 'blend', 'Grammar', 'Pip', 'clouds', 'guineas', 'sank', 'Mahomet', 'uncracked', 'shook', 'memorable', 'professors', 'warfare', 'splinters', 'rows', 'dimly', 'AZORE', 'carpenter', '1492', 'quarrel', 'expected', 'afar', 'FORESAIL', 'warped', 'lump', 'cultivate', 'alternately', 'scared', 'FISH', 'insured', 'Attend', 'plainest', 'imitated', 'pedlars', 'Bashaw', 'QUEEN', 'published', 'proceeding', 'terms', 'historians', 'vanity', 'dearly', 'clearings', 'Apollo', 'pageant', 'dominion', 'Delta', 'firmly', 'archipelagoes', 'Colonies', 'equity', 'rainbowed', 'host', 'Launched', 'missent', 'tapping', 'hemp', 'appeals', 'E', 'Kentuckian', 'correspondence', 'dissolutions', 'Gurry', 'Miserable', 'ferule', 'hypothesis', 'contortions', 'unremoved', 'gag', 'disembowelled', 'disconnected', 'who', 'bumpkin', 'incarnate', 'evening', 'Linnaeus', 'Prairie', 'assure', 'starlight', 'slightest', 'enhancing', 'heigh', 'caput', 'fixed', 'gangs', 'Two', 'purchasing', 'rushed', 'derision', 'Kings', 'discharged', 'twigged', 'sleeplessness', 'bumps', 'sanguinary', 'meadow', 'AUTHOR', 'benevolence', 'gas', 'keeper', 'country', 'Next', 'reddish', 'regularity', 'crossed', 'overspread', 'm', 'intertangled', 'befallen', 'fancy', 'decay', 'clashing', 'remains', 'phantoms', 'prowling', 'forms', 'flail', 'downcast', 'gasp', 'divorced', 'COMMODORE', 'fooling', 'intervals', 'inexorable', 'slided', '....', 'plaguey', 'manoeuvred', 'inferior', 'Case', 'misdoubt', 'intermission', 'banished', 'narwhales', 'spirits', 'laws', 'Flukes', 'clingest', 'Wet', 'promontories', 'Gayer', 'peaking', 'Secretary', 'hooped', 'innocently', 'scalding', 'twinkling', 'Scroll', 'Morning', 'unexpected', 'recrossed', 'fleeces', 'Justice', 'Afric', 'miner', 'indignity', 'ay', 'cruise', 'ether', 'farrago', 'warranted', 'mutters', 'panting', 'stains', 'rind', 'expending', 'Swackhammer', 'act', 'opened', 'submits', 'broker', 'insurgents', 'ignited', 'satirizing', 'noses', 'grog', 'darkling', 'knobs', 'creamy', 'settling', 'invisible', 'tallied',  ...

# %% [markdown]
# I would say the above condition checks if entire words in the sentence are present in the text1
#
# Since the entire set of words are not present in the text1 it returns false
#
# One practical example i would think of is set(user_passwords) < set(common_passwords) choosing the passwords aptly
#
# eg : Choosing 8 character passwords for signing up
